# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
from sklearn.model_selection import train_test_split 
import keras 
import sklearn
from keras.models import Sequential 
from keras.layers import InputLayer 
from keras.layers import Dense 
from keras.layers import Dropout 
from keras.constraints import maxnorm

# %%
df=pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#['tenure','MonthlyCharges','Total Charges']

# %%
df.SeniorCitizen.replace([0, 1], ["No", "Yes"], inplace= True) 
df.TotalCharges.replace([" "], ["0"], inplace= True) 
df.TotalCharges = df.TotalCharges.astype(float)
cID = df.customerID 
df.Churn.replace(["Yes", "No"], [1, 0], inplace= True)
df.drop("customerID", axis= 1, inplace= True)

# %%
df_int=df[['tenure','MonthlyCharges','TotalCharges']]

# %%
# example of a normalization
from numpy import asarray
from sklearn.preprocessing import MinMaxScaler
# define min max scaler
scaler = MinMaxScaler()
# transform data
scaled = scaler.fit_transform(df_int)
print(scaled)
# Out:
# [[0.01388889 0.11542289 0.00343704]
#  [0.47222222 0.38507463 0.21756402]
#  [0.02777778 0.35422886 0.01245279]
#  ...
#  [0.15277778 0.11293532 0.03989153]
#  [0.05555556 0.55870647 0.03530306]
#  [0.91666667 0.86965174 0.78810105]]

# %%
df.drop("tenure", axis= 1, inplace= True) 
df.drop("MonthlyCharges", axis= 1, inplace= True) 
df.drop("TotalCharges", axis= 1, inplace= True)

# %%
tenure=[i[0] for i in scaled]
monthly=[i[1] for i in scaled]
total=[i[2] for i in scaled]

# %%
tenure = np.array(tenure)
monthly = np.array(monthly)
total = np.array(total)

# %%
df['tenure'] = tenure.tolist()
df['MonthlyCharges'] = monthly.tolist()
df['TotalCharges'] = total.tolist()

# %%
df
# Out:
#       gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female            No     Yes         No           No  No phone service
# 1       Male            No      No         No          Yes                No
# 2       Male            No      No         No          Yes                No
# 3       Male            No      No         No           No  No phone service
# 4     Female            No      No         No          Yes                No
# ...      ...           ...     ...        ...          ...               ...
# 7038    Male            No     Yes        Yes          Yes               Yes
# 7039  Female            No     Yes        Yes          Yes               Yes
# 7040  Female            No     Yes        Yes           No  No phone service
# 7041    Male           Yes     Yes         No          Yes               Yes
# 7042    Male            No      No         No          Yes                No
#
# ...

# %%
data = pd.get_dummies(df)

# %%
data
# Out:
#       Churn    tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0         0  0.013889        0.115423      0.003437              1
# 1         0  0.472222        0.385075      0.217564              0
# 2         1  0.027778        0.354229      0.012453              0
# 3         0  0.625000        0.239303      0.211951              0
# 4         1  0.027778        0.521891      0.017462              1
# ...     ...       ...             ...           ...            ...
# 7038      0  0.333333        0.662189      0.229194              0
# 7039      0  1.000000        0.845274      0.847792              1
# 7040      0  0.152778        0.112935      0.039892              1
# 7041      1  0.055556        0.558706      0.035303              0
# 7042      0  0.916667        0.869652      0.788101              0
#
#       gender_Male  SeniorCitizen_No  SeniorCitizen_Yes  Partner_No  \
# 0               0                 1                  0           0
# ...

# %%
X = data.drop("Churn", axis= 1) 
y = data.Churn

# %%
X
# Out:
#         tenure  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0     0.013889        0.115423      0.003437              1            0
# 1     0.472222        0.385075      0.217564              0            1
# 2     0.027778        0.354229      0.012453              0            1
# 3     0.625000        0.239303      0.211951              0            1
# 4     0.027778        0.521891      0.017462              1            0
# ...        ...             ...           ...            ...          ...
# 7038  0.333333        0.662189      0.229194              0            1
# 7039  1.000000        0.845274      0.847792              1            0
# 7040  0.152778        0.112935      0.039892              1            0
# 7041  0.055556        0.558706      0.035303              0            1
# 7042  0.916667        0.869652      0.788101              0            1
#
#       SeniorCitizen_No  SeniorCitizen_Yes  Partner_No  Partner_Yes  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=45)

# %%
model = Sequential()
model.add(Dense(16, activation='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(16, activation='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss = "binary_crossentropy", optimizer = 'adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=35, batch_size=50)
# Out:
# Epoch 1/35
# 113/113 [==============================] - 1s 5ms/step - loss: 0.5532 - accuracy: 0.7025 - val_loss: 0.4541 - val_accuracy: 0.7566
# Epoch 2/35
# 113/113 [==============================] - 0s 3ms/step - loss: 0.4667 - accuracy: 0.7620 - val_loss: 0.4252 - val_accuracy: 0.8034
# Epoch 3/35
# 113/113 [==============================] - 0s 3ms/step - loss: 0.4508 - accuracy: 0.7787 - val_loss: 0.4177 - val_accuracy: 0.8077
# Epoch 4/35
# 113/113 [==============================] - 0s 3ms/step - loss: 0.4446 - accuracy: 0.7790 - val_loss: 0.4154 - val_accuracy: 0.8133
# Epoch 5/35
# 113/113 [==============================] - 0s 3ms/step - loss: 0.4389 - accuracy: 0.7865 - val_loss: 0.4149 - val_accuracy: 0.8077
# Epoch 6/35
# 113/113 [==============================] - 0s 3ms/step - loss: 0.4366 - accuracy: 0.7882 - val_loss: 0.4132 - val_accuracy: 0.8105
# Epoch 7/35
# ...

# %%
res=model.predict(X)
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ec779ec40ce> in <module>()
# ----> 1 res=model.predict(X)
#       2 res
#
# NameError: name 'model' is not defined

# %%
res1=[]
for i in res:
  if i>0.4657:
    res1.append(1)
  else:
    res1.append(0)

# %%
arr=sklearn.metrics.confusion_matrix(y_test, res1)

# %%
(arr[0][0]+arr[1][1])/(arr[0][0]+arr[1][1]+arr[0][1]+arr[1][0])
# Out:
# 0.8147622427253371

# %%
res = np.array(res)

# %%
df['Res'] = res.tolist()

# %%
df
# Out:
#       gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female            No     Yes         No           No  No phone service
# 1       Male            No      No         No          Yes                No
# 2       Male            No      No         No          Yes                No
# 3       Male            No      No         No           No  No phone service
# 4     Female            No      No         No          Yes                No
# ...      ...           ...     ...        ...          ...               ...
# 7038    Male            No     Yes        Yes          Yes               Yes
# 7039  Female            No     Yes        Yes          Yes               Yes
# 7040  Female            No     Yes        Yes           No  No phone service
# 7041    Male           Yes     Yes         No          Yes               Yes
# 7042    Male            No      No         No          Yes                No
#
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/Hackathon/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df['Res'] = res.tolist()

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df.to_csv('file.csv')

# %%
df
# Out:
#       gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female            No     Yes         No           No  No phone service
# 1       Male            No      No         No          Yes                No
# 2       Male            No      No         No          Yes                No
# 3       Male            No      No         No           No  No phone service
# 4     Female            No      No         No          Yes                No
# ...      ...           ...     ...        ...          ...               ...
# 7038    Male            No     Yes        Yes          Yes               Yes
# 7039  Female            No     Yes        Yes          Yes               Yes
# 7040  Female            No     Yes        Yes           No  No phone service
# 7041    Male           Yes     Yes         No          Yes               Yes
# 7042    Male            No      No         No          Yes                No
#
# ...

# %%
df['customerID']=cID

# %%
df
# Out:
#       gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female            No     Yes         No           No  No phone service
# 1       Male            No      No         No          Yes                No
# 2       Male            No      No         No          Yes                No
# 3       Male            No      No         No           No  No phone service
# 4     Female            No      No         No          Yes                No
# ...      ...           ...     ...        ...          ...               ...
# 7038    Male            No     Yes        Yes          Yes               Yes
# 7039  Female            No     Yes        Yes          Yes               Yes
# 7040  Female            No     Yes        Yes           No  No phone service
# 7041    Male           Yes     Yes         No          Yes               Yes
# 7042    Male            No      No         No          Yes                No
#
# ...
