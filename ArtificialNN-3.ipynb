# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt 
from sklearn.model_selection import train_test_split 
from sklearn.cluster import KMeans
import keras 
from keras.models import Sequential 
from keras.layers import InputLayer 
from keras.layers import Dense 
from keras.layers import Dropout 
from keras.constraints import maxnorm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv("/content/drive/MyDrive/Hackathon/Telco.csv")

# %%
data.SeniorCitizen.replace([0, 1], ["No", "Yes"], inplace= True) 
data.TotalCharges.replace([" "], ["0"], inplace= True) 
data.TotalCharges = data.TotalCharges.astype(float) 
data.drop("customerID", axis= 1, inplace= True) 
data.Churn.replace(["Yes", "No"], [1, 0], inplace= True)

# %%
data.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            No     Yes         No       1           No
# 1    Male            No      No         No      34          Yes
# 2    Male            No      No         No       2          Yes
# 3    Male            No      No         No      45           No
# 4  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
z=(data['tenure'].to_numpy()).reshape(-1,1)
#print(z)
kmeanstenure=KMeans(n_clusters=3,random_state=0).fit(z)
kmeanstenure.labels_
data['tenure_clustered']=kmeanstenure.labels_
tenurecount0=0
tenurecount1=0
tenurecount2=0
tenure0=0
tenure1=0
tenure2=0
for i in range(0,7043):
  if(data['tenure_clustered'][i]==0):
    tenurecount0=tenurecount0+1
    tenure0=tenure0+data['Churn'][i]
  elif(data['tenure_clustered'][i]==1):
    tenurecount1=tenurecount1+1
    tenure1=tenure1+data['Churn'][i]
  elif(data['tenure_clustered'][i]==2):
    tenurecount2=tenurecount2+1
    tenure2=tenure2+data['Churn'][i]
probten0=tenure0/tenurecount0
probten1=tenure1/tenurecount1
probten2=tenure2/tenurecount2
print(probten0)
print(probten1)
print(probten2)
(data['TotalCharges'].isnull()).count()
# Out:
# 0.2102803738317757
# 0.4346768589298124
# 0.09513175524787852
# 7043

# %%
z1=(data['MonthlyCharges'].to_numpy()).reshape(-1,1)
#print(z)
kmeansmonthly=KMeans(n_clusters=3,random_state=0).fit(z1)
data['MonthlyCharges_clustered']=kmeansmonthly.labels_
monthcount0=0
monthcount1=0
monthcount2=0
month0=0
month1=0
month2=0
for i in range(0,7043):
  if(data['MonthlyCharges_clustered'][i]==0):
    monthcount0=monthcount0+1
    month0=month0+data['Churn'][i]
  elif(data['MonthlyCharges_clustered'][i]==1):
    monthcount1=monthcount1+1
    month1=month1+data['Churn'][i]
  elif(data['MonthlyCharges_clustered'][i]==2):
    monthcount2=monthcount2+1
    month2=month2+data['Churn'][i]
probmon0=month0/monthcount0
probmon1=month1/monthcount1
probmon2=month2/monthcount2
print(probmon0)
print(probmon1)
print(probmon2)
data
# Out:
# 0.2831621259490844
# 0.34546703296703296
# 0.12103594080338266
#       gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female            No     Yes         No       1           No
# 1       Male            No      No         No      34          Yes
# 2       Male            No      No         No       2          Yes
# 3       Male            No      No         No      45           No
# 4     Female            No      No         No       2          Yes
# ...      ...           ...     ...        ...     ...          ...
# 7038    Male            No     Yes        Yes      24          Yes
# 7039  Female            No     Yes        Yes      72          Yes
# 7040  Female            No     Yes        Yes      11           No
# 7041    Male           Yes     Yes         No       4          Yes
# 7042    Male            No      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
z2=(data['TotalCharges'].to_numpy()).reshape(-1,1)
#print(z)
#kmeanstotal=KMeans(n_clusters=3,random_state=0).fit(z2)
#data['TotalCharges_clustered']=kmeanstotal.labels_
#totalcount0=0
#totalcount1=0
#totalcount2=0
#total0=0
#total1=0
#total2=0
#for i in range(0,7043):
 # if(data['TotalCharges_clustered'][i]==0):
  #  totalcount0=totalcount0+1
   # total0=total0+data['Churn'][i]
 # elif(data['TotalCharges_clustered'][i]==1):
   # totalcount1=totalcount1+1
   # total1=total1+data['Churn'][i]
  #elif(data['TotalCharges_clustered'][i]==2):
  #totalcount2=totalcount2+1
   # total2=total2+data['Churn'][i]
#probtot0=total0/totalcount0
#probtot1=total1/totalcount1
#probtot2=total2/totalcount2
#print(probtot0)
#print(probtot1)
#print(probtot2)
#data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-c0e2a9d59404> in <module>()
#       1 z2=(data['TotalCharges'].to_numpy()).reshape(-1,1)
#       2 #print(z)
# ----> 3 kmeanstotal=KMeans(n_clusters=3,random_state=0).fit(z2)
#       4 data['TotalCharges_clustered']=kmeanstotal.labels_
#       5 totalcount0=0
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1141             order="C",
#    1142             copy=self.copy_x,
# -> 1143             accept_large_sparse=False,
#    1144         )
#    1145
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# ...

# %%
data = pd.get_dummies(data)

# %%
data.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges  Churn  gender_Female  gender_Male  \
# 0       1           29.85         29.85      0              1            0
# 1      34           56.95       1889.50      0              0            1
# 2       2           53.85        108.15      1              0            1
# 3      45           42.30       1840.75      0              0            1
# 4       2           70.70        151.65      1              1            0
#
#    SeniorCitizen_No  SeniorCitizen_Yes  Partner_No  Partner_Yes  ...  \
# 0                 1                  0           0            1  ...
# 1                 1                  0           1            0  ...
# 2                 1                  0           1            0  ...
# 3                 1                  0           1            0  ...
# 4                 1                  0           1            0  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# ...

# %%
res=data['Contract_One year'].value_counts()[1]
print(len(X))
OneYear=0
count1=0
count=0
month=0
twoyear=0
count2=0
for i in range(0,7043):
  if (data['Contract_One year'][i])==1:
    count=count+1
    OneYear=OneYear+data['Churn'][i]
  elif (data['Contract_Month-to-month'][i]==1):
    count1=count1+1
    month=month+data['Churn'][i]
  elif (data['Contract_Two year'][i]==1):
    count2=count2+1
    twoyear=twoyear+data['Churn'][i]
ProbOne=OneYear/count
ProbMonth=month/count1
ProbTwo=twoyear/count2
print(ProbOne)
print(ProbMonth)
print(ProbTwo)
print(OneYear)
print(res)
X = data.drop("Churn", axis= 1) 
y = data.Churn
# Out:
# 7043
# 0.11269517990495587
# 0.4270967741935484
# 0.02831858407079646
# 166
# 1473

# %%
count3=0
NoNet=0
for i in range(0,7043):
  if(data['InternetService_No'][i]==1):
    count3=count3+1
    NoNet=NoNet+data['Churn'][i]
probNonet=NoNet/count3
print(probNonet)
# Out:
# 0.07404980340760157

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state= 0)

# %%
model = Sequential()

# %%
model.add(Dense(8, input_dim=46, activation='relu', kernel_constraint=maxnorm(3)))

# %%
model.add(Dense(8, activation='relu', kernel_constraint=maxnorm(3)))

# %%
model.add(Dropout(rate=0.2))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 8)                 376
#
#  dense_10 (Dense)            (None, 8)                 72
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
#  dense_11 (Dense)            (None, 1)                 9
#
# ...
# Total params: 457
# Trainable params: 457
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = "binary_crossentropy", optimizer = 'adam', metrics=['acc'])

# %%
history = model.fit(X_train, y_train,validation_data=(X_test,y_test),epochs=40, batch_size=10)
# Out:
# Epoch 1/40
# 564/564 [==============================] - 2s 2ms/step - loss: nan - acc: 0.6793 - val_loss: nan - val_acc: 0.7388
# Epoch 2/40
# 564/564 [==============================] - 1s 2ms/step - loss: nan - acc: 0.7336 - val_loss: nan - val_acc: 0.7388
# Epoch 3/40
# 564/564 [==============================] - 1s 2ms/step - loss: nan - acc: 0.7336 - val_loss: nan - val_acc: 0.7388
# Epoch 4/40
# 564/564 [==============================] - 1s 2ms/step - loss: nan - acc: 0.7336 - val_loss: nan - val_acc: 0.7388
# Epoch 5/40
# 564/564 [==============================] - 1s 2ms/step - loss: nan - acc: 0.7336 - val_loss: nan - val_acc: 0.7388
# Epoch 6/40
# 564/564 [==============================] - 1s 2ms/step - loss: nan - acc: 0.7336 - val_loss: nan - val_acc: 0.7388
# Epoch 7/40
# 564/564 [==============================] - 1s 2ms/step - loss: nan - acc: 0.7336 - val_loss: nan - val_acc: 0.7388
# Epoch 8/40
# ...

# %%
res=model.predict(X_test)

# %%
res
# Out:
# array([[nan],
#        [nan],
#        [nan],
#        ...,
#        [nan],
#        [nan],
#        [nan]], dtype=float32)
